# %%
import os
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("ggplot")
# %matplotlib inline

from pathlib import Path
# !pip install pandas_path
from pandas_path import path

# !pip install rasterio
import rasterio

from tqdm import tqdm_notebook, tnrange
from itertools import chain
from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from sklearn.model_selection import train_test_split

import tensorflow as tf

from keras.models import Model, load_model
from keras.layers import Input, BatchNormalization, Activation, Dense, Dropout
from keras.layers.core import Lambda, RepeatVector, Reshape
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D, GlobalMaxPool2D
from keras.layers.merge import concatenate, add
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
# Out:
# Requirement already satisfied: pandas_path in /usr/local/lib/python3.7/dist-packages (0.3.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from pandas_path) (4.6.4)
# Requirement already satisfied: pandas>=0.23 in /usr/local/lib/python3.7/dist-packages (from pandas_path) (1.1.5)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23->pandas_path) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23->pandas_path) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23->pandas_path) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.23->pandas_path) (1.15.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->pandas_path) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->pandas_path) (3.5.0)
# Requirement already satisfied: rasterio in /usr/local/lib/python3.7/dist-packages (1.2.6)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.7/dist-packages (from rasterio) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from rasterio) (1.19.5)
# Requirement already satisfied: attrs in /usr/local/lib/python3.7/dist-packages (from rasterio) (21.2.0)
# Requirement already satisfied: snuggs>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from rasterio) (1.4.7)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from rasterio) (2021.5.30)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.7/dist-packages (from rasterio) (1.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from rasterio) (57.4.0)
# Requirement already satisfied: affine in /usr/local/lib/python3.7/dist-packages (from rasterio) (2.3.0)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.7/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: pyparsing>=2.1.6 in /usr/local/lib/python3.7/dist-packages (from snuggs>=1.4.1->rasterio) (2.4.7)

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Following the tutorial at https://www.depends-on-the-definition.com/unet-keras-segmenting-images/

# %% [markdown]
# ## Load the training dataframe

# %%
# This is where our downloaded images and metadata live locally
#DATA_PATH = Path.cwd().parent / "runtime" / "data" / "train_features"
DATA_PATH = Path.cwd().parent / "content" / "drive" / "MyDrive" / "DATA SCIENCE" / "data google colab" / "floodwater" / "train_features"
train_metadata = pd.read_csv(
    DATA_PATH / "flood-training-metadata.csv", parse_dates=["scene_start"]
)

# %%
#adding the path to the images and labels in the dataframe
train_metadata["feature_path"] = (
    str(DATA_PATH / "train_features")
    / train_metadata.image_id.path.with_suffix(".tif").path
)

train_metadata["label_path"] = (
    str(DATA_PATH / "train_labels")
    / train_metadata.chip_id.path.with_suffix(".tif").path
)

# %%
train_metadata['feature_path'][0]
# Out:
# '/content/drive/MyDrive/DATA SCIENCE/data google colab/floodwater/train_features/train_features/awc00_vh.tif'

# %% [markdown]
# ## Split the training data into train and test

# %%
random.seed(0)  # set a seed for reproducibility

# Sample 3 random floods for validation set
flood_ids = train_metadata.flood_id.unique().tolist()
val_flood_ids = random.sample(flood_ids, 3)
val_flood_ids
# Out:
# ['kuo', 'wvy', 'awc']

# %%
test = train_metadata[train_metadata.flood_id.isin(val_flood_ids)]
train = train_metadata[~train_metadata.flood_id.isin(val_flood_ids)]

# %%
def get_paths_by_chip(image_level_df):
    """
    Function that take as input the meta_dataframe
    and return a dataframe with the chip id and both path for vv and vh.
    """
    paths = []
    for chip, group in image_level_df.groupby("chip_id"):
        vv_path = group[group.polarization == "vv"]["feature_path"].values[0]
        vh_path = group[group.polarization == "vh"]["feature_path"].values[0]
        paths.append([chip, vv_path, vh_path])
    return pd.DataFrame(paths, columns=["chip_id", "vv_path", "vh_path"])

# %%
# Separate features from labels
test_meta_x = get_paths_by_chip(test)
test_meta_y = test[["chip_id", "label_path"]].drop_duplicates().reset_index(drop=True)

train_meta_x = get_paths_by_chip(train)
train_meta_y = train[["chip_id", "label_path"]].drop_duplicates().reset_index(drop=True)

# %% [markdown]
# ## Get the images from the train and test metadata

# %%
def numpy_mask(image_path):
    with rasterio.open(image_path) as img:
        metadata = img.meta
        bounds = img.bounds
        data = img.read(1)  # read a single band

    with rasterio.open(image_path) as img:
        return img.read(1, masked=True)

# %%
def get_images(df, train=True):
    images = []
    
    #features
    if df.shape[1] == 3:
        for row in df.index:
            
            with rasterio.open(df.iloc[row].vv_path) as vv:
                vv_path = vv.read(1)
                #img = vv.read(1)
            with rasterio.open(df.iloc[row].vh_path) as vh:
                vh_path = vh.read(1)
            img = np.stack([vv_path, vh_path], axis=-1)
            
            #img = vv_path

            # Min-max normalization
            #min_norm = -77
            #max_norm = 26
            #img = np.clip(img, min_norm, max_norm)
            #img = (img - min_norm) / (max_norm - min_norm)
            
            #img = np.transpose(img, [2, 0, 1])
        
            #img = np.expand_dims(img, axis=2)
        
            images.append(img)
            
            #print(images.shape)
        
    #labels
    if df.shape[1] == 2:
        for path in df['label_path'].to_list():
            with rasterio.open(path) as lp:
                img = lp.read(1)
            
            images.append(img)
            
    return images

# %%
train_x = np.array(get_images(train_meta_x))
train_y = np.array(get_images(train_meta_y))
test_x = np.array(get_images(test_meta_x))
test_y = np.array(get_images(test_meta_y))

# %%
train_x.shape
# Out:
# (430, 512, 512, 2)

# %%
# f, ax = plt.subplots(1, 2, figsize=(15, 15))

# #visualize radar image
# ax[0].imshow(test_x[0])
# ax[0].set_title("Vertical-vertical band")

# ax[1].imshow(test_y[0])
# ax[1].set_title("label")

# plt.show()

# %% [markdown]
# # Unet model

# %%
def conv2d_block(input_tensor, n_filters, kernel_size=3, batchnorm=True):
    # first layer
    x = Conv2D(filters=n_filters, kernel_size=(kernel_size, kernel_size), kernel_initializer="he_normal",
               padding="same")(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation("relu")(x)
    # second layer
    x = Conv2D(filters=n_filters, kernel_size=(kernel_size, kernel_size), kernel_initializer="he_normal",
               padding="same")(x)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation("relu")(x)
    return x

# %%
def get_unet(input_img, n_filters=16, dropout=0.5, batchnorm=True):
    # contracting path
    c1 = conv2d_block(input_img, n_filters=n_filters*1, kernel_size=3, batchnorm=batchnorm)
    p1 = MaxPooling2D((2, 2)) (c1)
    p1 = Dropout(dropout*0.5)(p1)

    c2 = conv2d_block(p1, n_filters=n_filters*2, kernel_size=3, batchnorm=batchnorm)
    p2 = MaxPooling2D((2, 2)) (c2)
    p2 = Dropout(dropout)(p2)

    c3 = conv2d_block(p2, n_filters=n_filters*4, kernel_size=3, batchnorm=batchnorm)
    p3 = MaxPooling2D((2, 2)) (c3)
    p3 = Dropout(dropout)(p3)

    c4 = conv2d_block(p3, n_filters=n_filters*8, kernel_size=3, batchnorm=batchnorm)
    p4 = MaxPooling2D(pool_size=(2, 2)) (c4)
    p4 = Dropout(dropout)(p4)
    
    c5 = conv2d_block(p4, n_filters=n_filters*16, kernel_size=3, batchnorm=batchnorm)
    
    # expansive path
    u6 = Conv2DTranspose(n_filters*8, (3, 3), strides=(2, 2), padding='same') (c5)
    u6 = concatenate([u6, c4])
    u6 = Dropout(dropout)(u6)
    c6 = conv2d_block(u6, n_filters=n_filters*8, kernel_size=3, batchnorm=batchnorm)

    u7 = Conv2DTranspose(n_filters*4, (3, 3), strides=(2, 2), padding='same') (c6)
    u7 = concatenate([u7, c3])
    u7 = Dropout(dropout)(u7)
    c7 = conv2d_block(u7, n_filters=n_filters*4, kernel_size=3, batchnorm=batchnorm)

    u8 = Conv2DTranspose(n_filters*2, (3, 3), strides=(2, 2), padding='same') (c7)
    u8 = concatenate([u8, c2])
    u8 = Dropout(dropout)(u8)
    c8 = conv2d_block(u8, n_filters=n_filters*2, kernel_size=3, batchnorm=batchnorm)

    u9 = Conv2DTranspose(n_filters*1, (3, 3), strides=(2, 2), padding='same') (c8)
    u9 = concatenate([u9, c1], axis=3)
    u9 = Dropout(dropout)(u9)
    c9 = conv2d_block(u9, n_filters=n_filters*1, kernel_size=3, batchnorm=batchnorm)
    
    outputs = Conv2D(1, (1, 1), activation='sigmoid') (c9)
    model = Model(inputs=[input_img], outputs=[outputs])
    return model

# %%
input_img = Input((512, 512, 2), name='img')
model = get_unet(input_img, n_filters=16, dropout=0.05, batchnorm=True)

model.compile(optimizer=Adam(), loss="binary_crossentropy", metrics=["accuracy"])
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img (InputLayer)                [(None, 512, 512, 2) 0
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 512, 512, 16) 304         img[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 512, 512, 16) 64          conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 512, 512, 16) 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 512, 512, 16) 2320        activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 512, 512, 16) 64          conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 512, 512, 16) 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 256, 256, 16) 0           activation_19[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 256, 256, 16) 0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 256, 256, 32) 4640        dropout_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 256, 256, 32) 128         conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 256, 256, 32) 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 256, 256, 32) 9248        activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 256, 256, 32) 128         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 256, 256, 32) 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 128, 128, 32) 0           activation_21[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 128, 128, 32) 0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 128, 128, 64) 18496       dropout_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 128, 128, 64) 256         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 128, 128, 64) 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 128, 128, 64) 36928       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 128, 128, 64) 256         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 128, 128, 64) 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 64, 64, 64)   0           activation_23[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 64, 64, 64)   0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 64, 64, 128)  73856       dropout_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 64, 64, 128)  512         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 64, 64, 128)  0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 64, 64, 128)  147584      activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 64, 64, 128)  512         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 64, 64, 128)  0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 32, 32, 128)  0           activation_25[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 32, 32, 128)  0           max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 32, 32, 256)  295168      dropout_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 32, 32, 256)  1024        conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 32, 32, 256)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 32, 32, 256)  590080      activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 32, 32, 256)  1024        conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 32, 32, 256)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 64, 64, 128)  295040      activation_27[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 64, 64, 256)  0           conv2d_transpose_4[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 64, 64, 256)  0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 64, 64, 128)  295040      dropout_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 64, 64, 128)  512         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 64, 64, 128)  0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 64, 64, 128)  147584      activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 64, 64, 128)  512         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 64, 64, 128)  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 128, 128, 64) 73792       activation_29[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 128, 128, 128 0           conv2d_transpose_5[0][0]
#                                                                  activation_23[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 128, 128, 128 0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 128, 128, 64) 73792       dropout_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 128, 128, 64) 256         conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 128, 128, 64) 0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 128, 128, 64) 36928       activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 128, 128, 64) 256         conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 128, 128, 64) 0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 256, 256, 32) 18464       activation_31[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 256, 256, 64) 0           conv2d_transpose_6[0][0]
#                                                                  activation_21[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 256, 256, 64) 0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 256, 256, 32) 18464       dropout_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 256, 256, 32) 128         conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 256, 256, 32) 0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 256, 256, 32) 9248        activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 256, 256, 32) 128         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 256, 256, 32) 0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 512, 512, 16) 4624        activation_33[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 512, 512, 32) 0           conv2d_transpose_7[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 512, 512, 32) 0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 512, 512, 16) 4624        dropout_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 512, 512, 16) 64          conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 512, 512, 16) 0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 512, 512, 16) 2320        activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 512, 512, 16) 64          conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 512, 512, 16) 0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 512, 512, 1)  17          activation_35[0][0]
# ==================================================================================================
# Total params: 2,164,449
# Trainable params: 2,161,505
# Non-trainable params: 2,944
# __________________________________________________________________________________________________

# %%
callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=3, min_lr=0.00001, verbose=1),
    ModelCheckpoint('model_floodwater_unet_basic.h5', verbose=1, save_best_only=True, save_weights_only=False)
]

# %%
results = model.fit(train_x, train_y, batch_size=16, epochs=100, callbacks=callbacks,
                    validation_data=(test_x, test_y))
# Out:
# Epoch 1/100
# 27/27 [==============================] - 26s 896ms/step - loss: -22.5212 - accuracy: 0.6990 - val_loss: -71.6081 - val_accuracy: 0.3569
#
# Epoch 00001: val_loss improved from inf to -71.60809, saving model to model_floodwater_unet_basic.h5
# Epoch 2/100
# 27/27 [==============================] - 24s 893ms/step - loss: -41.0488 - accuracy: 0.7842 - val_loss: -104.7571 - val_accuracy: 0.2623
#
# Epoch 00002: val_loss improved from -71.60809 to -104.75706, saving model to model_floodwater_unet_basic.h5
# Epoch 3/100
# 27/27 [==============================] - 24s 876ms/step - loss: -47.8125 - accuracy: 0.8171 - val_loss: -100.7283 - val_accuracy: 0.5952
#
# Epoch 00003: val_loss did not improve from -104.75706
# Epoch 4/100
# 27/27 [==============================] - 22s 829ms/step - loss: -56.5915 - accuracy: 0.8311 - val_loss: -115.4240 - val_accuracy: 0.7346
#
# Epoch 00004: val_loss improved from -104.75706 to -115.42402, saving model to model_floodwater_unet_basic.h5
# Epoch 5/100
# 27/27 [==============================] - 23s 837ms/step - loss: -56.4924 - accuracy: 0.8430 - val_loss: -115.4686 - val_accuracy: 0.6798
#
# Epoch 00005: val_loss improved from -115.42402 to -115.46864, saving model to model_floodwater_unet_basic.h5
# Epoch 6/100
# 27/27 [==============================] - 24s 882ms/step - loss: -55.2370 - accuracy: 0.8455 - val_loss: -115.8660 - val_accuracy: 0.7819
#
# Epoch 00006: val_loss improved from -115.46864 to -115.86599, saving model to model_floodwater_unet_basic.h5
# Epoch 7/100
# 27/27 [==============================] - 24s 877ms/step - loss: -59.0800 - accuracy: 0.8528 - val_loss: -115.7798 - val_accuracy: 0.6746
#
# Epoch 00007: val_loss did not improve from -115.86599
# Epoch 8/100
# 27/27 [==============================] - 22s 833ms/step - loss: -59.5588 - accuracy: 0.8675 - val_loss: -115.6456 - val_accuracy: 0.5949
#
# Epoch 00008: val_loss did not improve from -115.86599
# Epoch 9/100
# 27/27 [==============================] - 24s 878ms/step - loss: -53.6126 - accuracy: 0.8634 - val_loss: -115.5598 - val_accuracy: 0.6369
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00009: val_loss did not improve from -115.86599
# Epoch 10/100
# 27/27 [==============================] - 24s 878ms/step - loss: -59.8564 - accuracy: 0.8768 - val_loss: -115.7860 - val_accuracy: 0.7197
#
# Epoch 00010: val_loss did not improve from -115.86599
# Epoch 11/100
# 27/27 [==============================] - 24s 878ms/step - loss: -52.8141 - accuracy: 0.8720 - val_loss: -115.9030 - val_accuracy: 0.8049
#
# Epoch 00011: val_loss improved from -115.86599 to -115.90296, saving model to model_floodwater_unet_basic.h5
# Epoch 12/100
# 27/27 [==============================] - 24s 877ms/step - loss: -59.9444 - accuracy: 0.8798 - val_loss: -115.9283 - val_accuracy: 0.8293
#
# Epoch 00012: val_loss improved from -115.90296 to -115.92833, saving model to model_floodwater_unet_basic.h5
# Epoch 13/100
# 27/27 [==============================] - 22s 834ms/step - loss: -61.0468 - accuracy: 0.8827 - val_loss: -115.9434 - val_accuracy: 0.8435
#
# Epoch 00013: val_loss improved from -115.92833 to -115.94344, saving model to model_floodwater_unet_basic.h5
# Epoch 14/100
# 27/27 [==============================] - 23s 836ms/step - loss: -60.2668 - accuracy: 0.8809 - val_loss: -115.9269 - val_accuracy: 0.8474
#
# Epoch 00014: val_loss did not improve from -115.94344
# Epoch 15/100
# 27/27 [==============================] - 24s 879ms/step - loss: -59.4150 - accuracy: 0.8855 - val_loss: -115.9608 - val_accuracy: 0.8631
#
# Epoch 00015: val_loss improved from -115.94344 to -115.96078, saving model to model_floodwater_unet_basic.h5
# Epoch 16/100
# 27/27 [==============================] - 23s 836ms/step - loss: -58.8681 - accuracy: 0.8889 - val_loss: -115.9678 - val_accuracy: 0.8678
#
# Epoch 00016: val_loss improved from -115.96078 to -115.96785, saving model to model_floodwater_unet_basic.h5
# Epoch 17/100
# 27/27 [==============================] - 24s 879ms/step - loss: -60.4490 - accuracy: 0.8880 - val_loss: -115.9842 - val_accuracy: 0.8729
#
# Epoch 00017: val_loss improved from -115.96785 to -115.98420, saving model to model_floodwater_unet_basic.h5
# Epoch 18/100
# 27/27 [==============================] - 23s 836ms/step - loss: -59.2513 - accuracy: 0.8895 - val_loss: -115.9787 - val_accuracy: 0.8769
#
# Epoch 00018: val_loss did not improve from -115.98420
# Epoch 19/100
# 27/27 [==============================] - 24s 878ms/step - loss: -58.7620 - accuracy: 0.8904 - val_loss: -115.9993 - val_accuracy: 0.8775
#
# Epoch 00019: val_loss improved from -115.98420 to -115.99927, saving model to model_floodwater_unet_basic.h5
# Epoch 20/100
# 27/27 [==============================] - 22s 835ms/step - loss: -55.6472 - accuracy: 0.8883 - val_loss: -115.9894 - val_accuracy: 0.8787
#
# Epoch 00020: val_loss did not improve from -115.99927
# Epoch 21/100
# 27/27 [==============================] - 22s 835ms/step - loss: -61.0815 - accuracy: 0.8929 - val_loss: -116.0056 - val_accuracy: 0.8797
#
# Epoch 00021: val_loss improved from -115.99927 to -116.00562, saving model to model_floodwater_unet_basic.h5
# Epoch 22/100
# 27/27 [==============================] - 22s 835ms/step - loss: -55.9617 - accuracy: 0.8885 - val_loss: -116.0071 - val_accuracy: 0.8806
#
# Epoch 00022: val_loss improved from -116.00562 to -116.00713, saving model to model_floodwater_unet_basic.h5
# Epoch 23/100
# 27/27 [==============================] - 22s 835ms/step - loss: -59.9045 - accuracy: 0.8915 - val_loss: -116.0137 - val_accuracy: 0.8816
#
# Epoch 00023: val_loss improved from -116.00713 to -116.01367, saving model to model_floodwater_unet_basic.h5
# Epoch 24/100
# 27/27 [==============================] - 24s 875ms/step - loss: -58.1462 - accuracy: 0.8929 - val_loss: -115.9728 - val_accuracy: 0.8752
#
# Epoch 00024: val_loss did not improve from -116.01367
# Epoch 25/100
# 27/27 [==============================] - 24s 877ms/step - loss: -61.0701 - accuracy: 0.8971 - val_loss: -116.0252 - val_accuracy: 0.8846
#
# Epoch 00025: val_loss improved from -116.01367 to -116.02515, saving model to model_floodwater_unet_basic.h5
# Epoch 26/100
# 27/27 [==============================] - 23s 836ms/step - loss: -60.7932 - accuracy: 0.8946 - val_loss: -116.0199 - val_accuracy: 0.8873
#
# Epoch 00026: val_loss did not improve from -116.02515
# Epoch 27/100
# 27/27 [==============================] - 23s 836ms/step - loss: -59.9879 - accuracy: 0.8953 - val_loss: -116.0308 - val_accuracy: 0.8886
#
# Epoch 00027: val_loss improved from -116.02515 to -116.03082, saving model to model_floodwater_unet_basic.h5
# Epoch 28/100
# 27/27 [==============================] - 22s 836ms/step - loss: -60.6116 - accuracy: 0.8969 - val_loss: -116.0262 - val_accuracy: 0.8896
#
# Epoch 00028: val_loss did not improve from -116.03082
# Epoch 29/100
# 27/27 [==============================] - 22s 834ms/step - loss: -59.5889 - accuracy: 0.9006 - val_loss: -116.0412 - val_accuracy: 0.8876
#
# Epoch 00029: val_loss improved from -116.03082 to -116.04121, saving model to model_floodwater_unet_basic.h5
# Epoch 30/100
# 27/27 [==============================] - 22s 834ms/step - loss: -60.8874 - accuracy: 0.8989 - val_loss: -116.0018 - val_accuracy: 0.8884
#
# Epoch 00030: val_loss did not improve from -116.04121
# Epoch 31/100
# 27/27 [==============================] - 22s 835ms/step - loss: -57.4891 - accuracy: 0.8974 - val_loss: -116.0292 - val_accuracy: 0.8912
#
# Epoch 00031: val_loss did not improve from -116.04121
# Epoch 32/100
# 27/27 [==============================] - 23s 836ms/step - loss: -58.6771 - accuracy: 0.8966 - val_loss: -116.0510 - val_accuracy: 0.8913
#
# Epoch 00032: val_loss improved from -116.04121 to -116.05098, saving model to model_floodwater_unet_basic.h5
# Epoch 33/100
# 27/27 [==============================] - 24s 877ms/step - loss: -59.6186 - accuracy: 0.9022 - val_loss: -116.0486 - val_accuracy: 0.8925
#
# Epoch 00033: val_loss did not improve from -116.05098
# Epoch 34/100
# 27/27 [==============================] - 23s 837ms/step - loss: -61.1253 - accuracy: 0.9001 - val_loss: -116.0528 - val_accuracy: 0.8915
#
# Epoch 00034: val_loss improved from -116.05098 to -116.05283, saving model to model_floodwater_unet_basic.h5
# Epoch 35/100
# 27/27 [==============================] - 23s 837ms/step - loss: -57.0642 - accuracy: 0.8988 - val_loss: -116.0463 - val_accuracy: 0.8912
#
# Epoch 00035: val_loss did not improve from -116.05283
# Epoch 36/100
# 27/27 [==============================] - 23s 837ms/step - loss: -58.5874 - accuracy: 0.8989 - val_loss: -116.0542 - val_accuracy: 0.8895
#
# Epoch 00036: val_loss improved from -116.05283 to -116.05422, saving model to model_floodwater_unet_basic.h5
# Epoch 37/100
# 27/27 [==============================] - 24s 877ms/step - loss: -58.8215 - accuracy: 0.9008 - val_loss: -116.0534 - val_accuracy: 0.8919
#
# Epoch 00037: val_loss did not improve from -116.05422
# Epoch 38/100
# 27/27 [==============================] - 24s 877ms/step - loss: -59.9305 - accuracy: 0.9043 - val_loss: -116.0510 - val_accuracy: 0.8957
#
# Epoch 00038: val_loss did not improve from -116.05422
# Epoch 39/100
# 27/27 [==============================] - 22s 835ms/step - loss: -58.8982 - accuracy: 0.9050 - val_loss: -116.0659 - val_accuracy: 0.8965
#
# Epoch 00039: val_loss improved from -116.05422 to -116.06586, saving model to model_floodwater_unet_basic.h5
# Epoch 40/100
# 27/27 [==============================] - 22s 835ms/step - loss: -59.9415 - accuracy: 0.8993 - val_loss: -116.0215 - val_accuracy: 0.8912
#
# Epoch 00040: val_loss did not improve from -116.06586
# Epoch 41/100
# 27/27 [==============================] - 24s 878ms/step - loss: -60.0537 - accuracy: 0.9018 - val_loss: -116.0698 - val_accuracy: 0.8953
#
# Epoch 00041: val_loss improved from -116.06586 to -116.06979, saving model to model_floodwater_unet_basic.h5
# Epoch 42/100
# 27/27 [==============================] - 23s 836ms/step - loss: -60.3556 - accuracy: 0.9015 - val_loss: -116.0727 - val_accuracy: 0.8982
#
# Epoch 00042: val_loss improved from -116.06979 to -116.07273, saving model to model_floodwater_unet_basic.h5
# Epoch 43/100
# 27/27 [==============================] - 24s 879ms/step - loss: -61.1496 - accuracy: 0.8984 - val_loss: -116.0676 - val_accuracy: 0.8958
#
# Epoch 00043: val_loss did not improve from -116.07273
# Epoch 44/100
# 27/27 [==============================] - 22s 835ms/step - loss: -58.7302 - accuracy: 0.9015 - val_loss: -116.0655 - val_accuracy: 0.8946
#
# Epoch 00044: val_loss did not improve from -116.07273
# Epoch 45/100
# 27/27 [==============================] - 23s 837ms/step - loss: -59.7418 - accuracy: 0.9047 - val_loss: -116.0792 - val_accuracy: 0.8949
#
# Epoch 00045: val_loss improved from -116.07273 to -116.07919, saving model to model_floodwater_unet_basic.h5
# Epoch 46/100
# 27/27 [==============================] - 23s 837ms/step - loss: -61.2784 - accuracy: 0.9087 - val_loss: -116.0823 - val_accuracy: 0.8953
#
# Epoch 00046: val_loss improved from -116.07919 to -116.08232, saving model to model_floodwater_unet_basic.h5
# Epoch 47/100
# 27/27 [==============================] - 23s 837ms/step - loss: -61.2730 - accuracy: 0.9041 - val_loss: -115.9985 - val_accuracy: 0.8856
#
# Epoch 00047: val_loss did not improve from -116.08232
# Epoch 48/100
# 27/27 [==============================] - 23s 837ms/step - loss: -58.4903 - accuracy: 0.9086 - val_loss: -115.9747 - val_accuracy: 0.8830
#
# Epoch 00048: val_loss did not improve from -116.08232
# Epoch 49/100
# 27/27 [==============================] - 23s 836ms/step - loss: -61.2571 - accuracy: 0.9056 - val_loss: -116.0679 - val_accuracy: 0.8950
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00049: val_loss did not improve from -116.08232
# Epoch 50/100
# 27/27 [==============================] - 24s 878ms/step - loss: -60.8113 - accuracy: 0.9052 - val_loss: -116.0709 - val_accuracy: 0.8958
#
# Epoch 00050: val_loss did not improve from -116.08232
# Epoch 51/100
# 27/27 [==============================] - 24s 878ms/step - loss: -58.5890 - accuracy: 0.9017 - val_loss: -116.0697 - val_accuracy: 0.8972
#
# Epoch 00051: val_loss did not improve from -116.08232
# Epoch 52/100
# 27/27 [==============================] - 24s 878ms/step - loss: -56.5487 - accuracy: 0.9031 - val_loss: -116.0725 - val_accuracy: 0.8975
#
# Epoch 00052: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 00052: val_loss did not improve from -116.08232
# Epoch 53/100
# 27/27 [==============================] - 24s 878ms/step - loss: -61.2769 - accuracy: 0.9067 - val_loss: -116.0730 - val_accuracy: 0.8976
#
# Epoch 00053: val_loss did not improve from -116.08232
# Epoch 54/100
# 27/27 [==============================] - 23s 836ms/step - loss: -61.2918 - accuracy: 0.9107 - val_loss: -116.0744 - val_accuracy: 0.8974
#
# Epoch 00054: val_loss did not improve from -116.08232
# Epoch 55/100
# 27/27 [==============================] - 23s 838ms/step - loss: -61.2851 - accuracy: 0.9100 - val_loss: -116.0759 - val_accuracy: 0.8974
#
# Epoch 00055: val_loss did not improve from -116.08232
# Epoch 56/100
# 27/27 [==============================] - 24s 879ms/step - loss: -60.5144 - accuracy: 0.9048 - val_loss: -116.0662 - val_accuracy: 0.8988
#
# Epoch 00056: val_loss did not improve from -116.08232
# Epoch 00056: early stopping

# %%
plt.figure(figsize=(8, 8))
plt.title("Learning curve")
plt.plot(results.history["loss"], label="loss")
plt.plot(results.history["val_loss"], label="val_loss")
plt.plot( np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("log_loss")
plt.legend();

# %%
# Evaluate on validation set (this must be equals to the best log_loss)
model.evaluate(test_x, test_y, verbose=1)
# Out:
# 4/4 [==============================] - 2s 341ms/step - loss: -116.0662 - accuracy: 0.8988
# [-116.06616973876953, 0.8988328576087952]

# %% [markdown]
# ## Predict output

# %%
# Predict on train, val and test
preds_train = model.predict(train_x, verbose=1)
preds_val = model.predict(test_x, verbose=1)

# Threshold predictions
preds_train_t = (preds_train > 0.5).astype(np.uint8)
preds_val_t = (preds_val > 0.5).astype(np.uint8)
# Out:
# 14/14 [==============================] - 6s 399ms/step
# 4/4 [==============================] - 1s 400ms/step

# %%
f, ax = plt.subplots(1, 3, figsize=(15, 15))

id = 1

#visualize radar image   x[:, :, 0]
ax[0].imshow(train_x[id][:, :, 0])
ax[0].set_title("Vertical-vertical band")

label = train_y[id]
label[label == 255] = 1
ax[1].imshow(label, "gray")
ax[1].set_title("label")

pred = preds_train_t[id][:, :, 0]
ax[2].imshow(pred, "gray")
ax[2].set_title("prediction")

plt.show()
